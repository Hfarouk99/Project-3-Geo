# %%
import os
import requests
import json
from dotenv import load_dotenv
import pandas as pd
import seaborn as sns
from pymongo import MongoClient
import geopandas as gpd
from cartoframes.viz import Map, Layer
import folium
from folium import Choropleth, Circle, Marker, Icon, Map
from folium.plugins import HeatMap, MarkerCluster
load_dotenv()
# Out:
# True

# %%
client = MongoClient("localhost:27017")
db = client["Ironhack"] # I or i 
client_id= os.getenv("Client_Id")
client_s= os.getenv("Client_Secret")
client_key= os.getenv("Key")

# %%
initial_lat = 34.0218593
initial_long = -118.498265

# %%
LA_map = folium.Map(location = [initial_lat, initial_long], zoom_start=11)
LA_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b32ba469e389eb0bb62e711cbe73ebec {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b32ba469e389eb0bb62e711cbe73ebec&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_b32ba469e389eb0bb62e711cbe73ebec = L.map(
#                 &quot;map_b32ba469e389eb0bb62e711cbe73ebec&quot;,
#                 {
#                     center: [34.0218593, -118.498265],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9405030f5ec6dda82e842d6853f380ba = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b32ba469e389eb0bb62e711cbe73ebec);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
db.list_collection_names()
# Out:
# ['bookstores',
#  'districts',
#  'nyrest',
#  'nyrestaurants.',
#  'restaurants',
#  'companies',
#  'distritos']

# %%
companies = db.get_collection('companies') # C or c

# %% [markdown]
# ### function for creating the dataframe of all the info needed

# %%
# function for creating the dataframe of all the info needed

# lets drop some more, one of the most important requiremetns is having design companies nearby.
# We should remove all comnaies that are not design companies 

def Company_in_cali(c):
    filter_ = {'$and':[{'offices': {'$exists': 1}},{'offices.latitude':{'$type':1}},{'offices.longitude':{'$type': 1}}]}
    projection = {"_id":0,'name':1,'founded_year':1,'offices.country_code':1,"offices.state_code":1,'offices.city':1,'offices.address1':1,'offices.address2':1,'offices.latitude':1,'offices.longitude':1}
    sorting = {'offices.country_code':-1}
    lis = list(companies.find(filter_, projection).sort("offices.country_code", -1))
    df = pd.DataFrame(lis).explode("offices").reset_index(drop=True)
    df = pd.concat([df, df["offices"].apply(pd.Series)], axis=1).reset_index(drop=True)
    df.dropna(subset=["latitude"],inplace=True)
    df.dropna(subset=["founded_year"],inplace=True)
    df.dropna(subset=["address1"],inplace=True)
    df.dropna(subset=["address2"],inplace=True)
    df.dropna(subset=["city"],inplace=True)
    newcols = [element for element in df.columns if element != 'offices']
    df=df[newcols].reset_index(drop=True)
    df=df[df["country_code"]=="USA"]
    df=df[df['state_code'] == 'CA'].reset_index(drop=True)
    df = df.drop(columns="founded_year")
    return df

# %%
df= Company_in_cali(companies)
df
# Out:
#                          name                          address1     address2  \
# 0                        Yola                201 Mission Street   Suite 2250
# 1                  Buongiorno                   485 Alberto Way    Suite 210
# 2                      InMobi                       475 Brannan    Suite 420
# 3                     LinQpay
# 4                     Sparkpr                   2 Bryant Street    Suite 100
# ...                       ...                               ...          ...
# 2396                 Cantimer                  3700 Haven Court
# 2397  Celestial Semiconductor  2635 North 1st Street, Suite 150
# 2398                 Purfresh                 1350 Willow Road,    Suite 102
# 2399                MyChances
# 2400                  Intergy            11875 Dublin Boulevard  Suite A-201
#
#                city state_code country_code   latitude   longitude
# 0     San Francisco         CA          USA  37.791115 -122.395475
# 1         Los Gatos         CA          USA  37.229898 -121.971853
# 2     San Francisco         CA          USA  37.446550 -122.170921
# 3          Carlsbad         CA          USA  33.095680 -117.244034
# 4     San Francisco         CA          USA  37.787394 -122.388442
# ...             ...        ...          ...        ...         ...
# 2396     Menlo Park         CA          USA  37.484616 -122.181753
# 2397       San Jose         CA          USA  37.386417 -121.929170
# 2398     Menlo Park         CA          USA  37.477008 -122.151599
# 2399     Menlo Park         CA          USA  37.448491 -122.180281
# 2400         Dublin         CA          USA  37.701940 -121.936698
#
# [2401 rows x 8 columns]

# %% [markdown]
# ## Dataframe of all the employees and their count and salaries

# %% [markdown]
# - 20 Designers
# - 5 UI/UX Engineers
# - 10 Frontend Developers
# - 15 Data Engineers
# - 5 Backend Developers
# - 20 Account Managers
# - 1 Maintenance guy that loves basketball
# - 10 Executives
# - 1 CEO/President.

# %%
# Dataframe of all the employees and their count and salaries

employee_table = {'Title': ['Game designer', 'UX/UI', 'Front-end developer', 'Data engineer', 'Back-end developer',
                      'Account manager', 'Maintenance guy', 'Executive', 'CEO' ],
                'Salary': [115568, 104266, 87240, 112493, 80258, 58670, 40482, 52522, 148598],
                'Count': [20, 5, 10, 15, 5, 20, 1, 10,1]
                 } 
# We can sue this to weigh our decision, Dani did something like this,
# I think its good for reasoning why something is more important than another
# salaries are from glassdoor and are average salaries 

df_employee_table = pd.DataFrame(employee_table).explode("Title")
df_employee_table['total spending'] = df_employee_table.eval('Salary*Count')
df_employee_table.sort_values(by=['total spending'], ascending=False)
# Out:
#                  Title  Salary  Count  total spending
# 0        Game designer  115568     20         2311360
# 3        Data engineer  112493     15         1687395
# 5      Account manager   58670     20         1173400
# 2  Front-end developer   87240     10          872400
# 7            Executive   52522     10          525220
# 1                UX/UI  104266      5          521330
# 4   Back-end developer   80258      5          401290
# 8                  CEO  148598      1          148598
# 6      Maintenance guy   40482      1           40482

# %% [markdown]
# ## Heatmapping function

# %%
def Heat_map_cali(df,radius):
    m = folium.Map(location = [34.0218593,-118.498265], zoom_start=10)
    HeatMap(data=df[["latitude","longitude"]],radius=radius).add_to(m)
    return m

# %%
Heat_map_cali(df,15)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_75cb760934f049a1d4c85b4ea9b4fa00 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@master/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_75cb760934f049a1d4c85b4ea9b4fa00&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_75cb760934f049a1d4c85b4ea9b4fa00 = L.map(
#                 &quot;map_75cb760934f049a1d4c85b4ea9b4fa00&quot;,
#                 {
#                     center: [34.0218593, -118.498265],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1aec80e5f8e8c0cf139d99f5440b6ece = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_75cb760934f049a1d4c85b4ea9b4fa00);
#
#
#             var heat_map_dcefe0dcb0bd73342083cc3deabfa86f = L.heatLayer(
#                 [[37.7911148, -122.3954751], [37.229898, -121.971853], [37.4465496, -122.1709208], [33.09568, -117.244034], [37.7873938, -122.3884419], [33.862748, -118.398841], [37.7736667, -122.4148917], [37.692934, -121.904945], [37.692934, -121.904945], [37.764726, -122.394523], [37.41605, -122.151801], [34.090368, -118.393064], [34.076179, -118.39417], [37.7768052, -122.4169244], [37.775196, -122.419204], [37.789634, -122.404052], [33.022176, -117.081406], [34.057498, -118.446596], [37.295005, -121.930035], [37.269175, -119.306607], [37.387845, -122.055197], [37.408802, -121.95377], [37.418531, -122.025485], [37.778613, -122.395289], [37.779558, -122.393041], [34.0263021, -118.380954], [34.1494713, -118.1327468], [34.017606, -118.487267], [37.788482, -122.409173], [32.902266, -117.20834], [37.697805, -121.907768], [37.390056, -122.067692], [37.78976, -122.402524], [37.421972, -122.084143], [33.658331, -117.861817], [37.789803, -122.389757], [34.019282, -118.494288], [37.4233896, -122.0899512], [37.627971, -122.426804], [34.051409, -118.254558], [37.392936, -122.07948], [37.384949, -121.96761], [37.762541, -122.397224], [37.757758, -122.388243], [37.559287, -122.302262], [37.269175, -119.306607], [37.780134, -122.396744], [37.421621, -122.137444], [37.793819, -122.395089], [37.7870842, -122.4038047], [34.155211, -118.756618], [37.786183, -122.402195], [33.991101, -118.468707], [37.7891086, -122.4016144], [37.484619, -122.206893], [34.0126379, -118.495155], [37.758113, -122.414689], [37.7791761, -122.4058887], [37.789268, -122.395184], [37.781427, -122.392144], [37.782103, -122.401116], [37.418531, -122.025485], [37.778076, -122.397977], [37.90077, -122.511687], [37.391502, -122.073463], [37.5108541, -122.2013557], [37.762681, -122.400909], [37.393679, -122.079017], [37.779507, -122.39071], [37.423258, -122.073635], [37.870744, -122.269259], [37.437328, -122.159928], [37.425801, -122.143701], [34.0906602, -118.3835957], [37.561877, -122.325248], [37.382162, -122.036301], [37.775196, -122.419204], [37.40047, -122.072981], [37.775196, -122.419204], [37.553121, -122.301534], [37.7618242, -122.3985871], [32.872081, -117.206292], [39.9195028, -105.1110024], [37.563585, -122.324621], [37.479952, -122.178557], [37.4219165, -122.0780632], [37.451958, -122.116026], [34.184598, -118.601532], [37.782263, -122.392142], [37.766909, -122.406676], [37.787183, -122.397759], [37.793703, -122.398479], [37.6637279, -121.8731805], [37.321798, -121.979453], [37.788668, -122.400558], [37.7753, -122.4186], [34.050887, -118.459995], [37.451026, -122.18676], [37.774321, -122.415375], [37.536172, -122.327323], [34.42071, -119.641821], [37.55909, -122.321836], [37.787092, -122.399972], [37.536172, -122.327323], [37.898575, -122.537302], [37.787683, -122.410943], [37.775196, -122.419204], [37.792394, -122.402349], [37.320052, -121.877636], [37.4484914, -122.1802812], [37.779392, -122.417928], [37.4858654, -122.2262606], [37.386376, -121.991471], [37.384651, -121.992132], [37.384651, -121.992132], [37.269175, -119.306607], [34.017506, -118.401579], [37.09024, -95.712891], [37.780883, -122.395257], [37.368594, -122.034021], [37.400465, -122.073003], [32.89746, -117.195414], [37.288974, -121.935688], [37.386665, -122.084171], [37.524729, -122.258037], [37.294465, -121.927696], [37.553743, -122.300246], [34.156802, -118.324987], [37.78554, -122.396689], [37.437328, -122.159928], [37.3927975, -122.0727749], [32.877656, -117.210595], [34.01676, -118.495566], [40.270666, -74.761403], [51.500152, -0.126236], [38.0729365, -122.1879633], [32.964294, -117.265191], [34.052187, -118.243425], [37.437328, -122.159928], [32.720656, -117.167831], [37.491356, -122.228843], [37.7909427, -122.4084994], [37.779507, -122.39071], [37.795555, -122.400729], [37.790998, -122.394668], [37.786942, -122.401245], [37.781557, -122.407959], [37.5646055, -122.3229235], [40.010492, -105.276843], [39.762314, -104.982256], [37.437328, -122.159928], [37.383779, -122.007172], [37.0902

# %% [markdown]
# ## Foursquare api Work soo far

# %%
query = {"offices.city": "Los Angeles"}
projection = {"_id":0,"name":1,"offices.city":1, "country_code":1,
              "offices.latitude":1, "offices.longitude":1,"office.city":1}

list(companies.find(query, projection))[:5]
# Out:
# [{'name': 'Helio',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.057498,
#     'longitude': -118.446596}]},
#  {'name': 'Stickam',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.051409,
#     'longitude': -118.254558}]},
#  {'name': 'Ustream',
#   'offices': [{'city': 'San Francisco',
#     'latitude': 37.392936,
#     'longitude': -122.07948},
#    {'city': 'Los Angeles', 'latitude': None, 'longitude': None},
#    {'city': 'Budapest', 'latitude': None, 'longitude': None}]},
#  {'name': 'TripUp',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.052187,
#     'longitude': -118.243425}]},
#  {'name': 'Eventful',
#   'offices': [{'city': 'San Diego',
#     'latitude': 32.872081,
#     'longitude': -117.206292},
#    {'city': 'Los Angeles', 'latitude': None, 'longitude': None}]}]

# %%
len(list(companies.find(query, projection)))
# Out:
# 219

# %%
LosAngeles = list(companies.find(query, projection))

# %%
LosAngeles
# Out:
# [{'name': 'Helio',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.057498,
#     'longitude': -118.446596}]},
#  {'name': 'Stickam',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.051409,
#     'longitude': -118.254558}]},
#  {'name': 'Ustream',
#   'offices': [{'city': 'San Francisco',
#     'latitude': 37.392936,
#     'longitude': -122.07948},
#    {'city': 'Los Angeles', 'latitude': None, 'longitude': None},
#    {'city': 'Budapest', 'latitude': None, 'longitude': None}]},
#  {'name': 'TripUp',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.052187,
#     'longitude': -118.243425}]},
#  {'name': 'Eventful',
#   'offices': [{'city': 'San Diego',
#     'latitude': 32.872081,
#     'longitude': -117.206292},
#    {'city': 'Los Angeles', 'latitude': None, 'longitude': None}]},
#  {'name': 'ScanScout',
#   'offices': [{'city': 'Boston',
#     'latitude': 42.340889,
#     'longitude': -71.051931},
#    {'city': 'New York', 'latitude': 40.739833, 'longitude': -73.993158},
#    {'city': 'Los Angeles', 'latitude': 34.050887, 'longitude': -118.459995}]},
#  {'name': 'WebbAlert',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.052187,
#     'longitude': -118.243425}]},
#  {'name': 'Revver',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.052187,
#     'longitude': -118.243425}]},
#  {'name': 'Social Platform',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.101617,
#     'longitude': -118.327071}]},
#  {'name': 'SuicideGirls',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.062262,
#     'longitude': -118.348198}]},
#  {'name': 'DAVE Networks',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 33.979033,
#     'longitude': -118.423423},
#    {'city': 'Marina Del Rey',
#     'latitude': 33.979506,
#     'longitude': -118.439787}]},
#  {'name': 'Shopzilla',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 37.09024,
#     'longitude': -95.712891},
#    {'city': 'London', 'latitude': None, 'longitude': None},
#    {'city': 'New York', 'latitude': None, 'longitude': None},
#    {'city': 'Chicago', 'latitude': None, 'longitude': None}]},
#  {'name': 'PriceGrabber',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 37.09024,
#     'longitude': -95.712891}]},
#  {'name': 'hulu',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.031276,
#     'longitude': -118.456806}]},
#  {'name': 'ElephantDrive',
#   'offices': [{'city': 'Los Angeles', 'latitude': None, 'longitude': None}]},
#  {'name': 'Musicshake',
#   'offices': [{'city': 'Los Angeles', 'latitude': None, 'longitude': None}]},
#  {'name': 'Orgoo',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.0481711,
#     'longitude': -118.4419012}]},
#  {'name': 'RotoHog',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 33.959799,
#     'longitude': -118.343938}]},
#  {'name': 'mEgo',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.064491,
#     'longitude': -118.42749}]},
#  {'name': 'StreetFire',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 33.982431,
#     'longitude': -118.426707}]},
#  {'name': 'Turn',
#   'offices': [{'city': 'Redwood City',
#     'latitude': 37.512253,
#     'longitude': -122.201099},
#    {'city': 'San Francisco', 'latitude': None, 'longitude': None},
#    {'city': 'New York', 'latitude': None, 'longitude': None},
#    {'city': 'Chicago', 'latitude': None, 'longitude': None},
#    {'city': 'Los Angeles', 'latitude': None, 'longitude': None},
#    {'city': '', 'latitude': None, 'longitude': None},
#    {'city': '', 'latitude': None, 'longitude': None}]},
#  {'name': 'Springbox',
#   'offices': [{'city': 'Austin',
#     'latitude': 30.269452,
#     'longitude': -97.742682},
#    {'city': 'Los Angeles',
#     'latitude': 34.0065488,
#     'longitude': -118.3923578}]},
#  {'name': 'Seethroo',
#   'offices': [{'city': 'Los Angeles', 'latitude': None, 'longitude': None}]},
#  {'name': 'RazorGator',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.047312,
#     'longitude': -118.445243}]},
#  {'name': 'Oversee',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.051368,
#     'longitude': -118.256305}]},
#  {'name': 'Zynga',
#   'offices': [{'city': 'San Francisco',
#     'latitude': 37.765158,
#     'longitude': -122.404234},
#    {'city': '', 'latitude': None, 'longitude': None},
#    {'city': 'Baltimore', 'latitude': None, 'longitude': None},
#    {'city': 'Los Angeles', 'latitude': None, 'longitude': None}]},
#  {'name': 'MetaNotes',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.128046,
#     'longitude': -118.289065}]},
#  {'name': 'PlanJam',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.059721,
#     'longitude': -118.425401}]},
#  {'name': 'E! Entertainment',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.062253,
#     'longitude': -118.3543243}]},
#  {'name': 'Jirbo',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.064629,
#     'longitude': -118.469316}]},
#  {'name': 'Gorilla Nation Media',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 33.988735,
#     'longitude': -118.368871},
#    {'city': 'New York', 'latitude': None, 'longitude': None},
#    {'city': 'Chicago', 'latitude': None, 'longitude': None},
#    {'city': 'Toronto', 'latitude': None, 'longitude': None},
#    {'city': 'San Francisco', 'latitude': None, 'longitude': None},
#    {'city': 'Sydney', 'latitude': None, 'longitude': None},
#    {'city': 'London', 'latitude': None, 'longitude': None},
#    {'city': 'Montreal', 'latitude': None, 'longitude': None}]},
#  {'name': 'Social Gaming Network',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 37.446823,
#     'longitude': -122.161523},
#    {'city': 'Beverly Hills',
#     'latitude': 34.0698494,
#     'longitude': -118.4054182}]},
#  {'name': 'Los Angeles Times Media Group',
#   'offices': [{'city': 'Los Angeles', 'latitude': None, 'longitude': None}]},
#  {'name': 'ePillager',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.029209,
#     'longitude': -118.289344}]},
#  {'name': 'JuicyCampus',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 33.954874,
#     'longitude': -118.396507}]},
#  {'name': 'ALi Corporation',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.0618146,
#     'longitude': -118.2899533}]},
#  {'name': 'Napster',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.080772,
#     'longitude': -118.3891962}]},
#  {'name': 'AtomicOnline',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 33.988735,
#     'longitude': -118.368871},
#    {'city': 'New York', 'latitude': None, 'longitude': None},
#    {'city': 'Chicago', 'latitude': None, 'longitude': None},
#    {'city': 'Scottsdale', 'latitude': None, 'longitude': None},
#    {'city': 'San Francisco', 'latitude': None, 'longitude': None}]},
#  {'name': 'SEO Intelligence',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.041037,
#     'longitude': -118.23341}]},
#  {'name': 'Taltopia',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.052187,
#     'longitude': -118.243425}]},
#  {'name': 'SmartRatings',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.047104,
#     'longitude': -118.434213}]},
#  {'name': 'DailyStrength',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.043948,
#     'longitude': -118.468204}]},
#  {'name': 'CrewedUp',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.089679,
#     'longitude': -118.292618}]},
#  {'name': 'Authenticlick',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.062504,
#     'longitude': -118.354605}]},
#  {'name': 'PeopleSupport',
#   'offices': [{'city': 'Los Angeles', 'latitude': None, 'longitude': None}]},
#  {'name': 'FASTALLEY',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.081952,
#     'longitude': -118.357658}]},
#  {'name': 'Wedding Channel',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.0486806,
#     'longitude': -118.2587784}]},
#  {'name': 'Causecast',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.018349,
#     'longitude': -118.486889}]},
#  {'name': 'iCrossing',
#   'offices': [{'city': 'Brighton, BN1 1ND',
#     'latitude': None,
#     'longitude': None},
#    {'city': 'Chicago', 'latitude': None, 'longitude': None},
#    {'city': 'Dallas', 'latitude': None, 'longitude': None},
#    {'city': 'Irvine', 'latitude': None, 'longitude': None},
#    {'city': '', 'latitude': None, 'longitude': None},
#    {'city': 'Los Angeles', 'latitude': None, 'longitude': None},
#    {'city': 'Munich', 'latitude': None, 'longitude': None},
#    {'city': 'New York', 'latitude': None, 'longitude': None},
#    {'city': 'Reston', 'latitude': None, 'longitude': None},
#    {'city': 'Salt Lake City', 'latitude': None, 'longitude': None},
#    {'city': 'San Francisco', 'latitude': None, 'longitude': None},
#    {'city': 'Scottsdale', 'latitude': None, 'longitude': None}]},
#  {'name': 'Magento',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.052187,
#     'longitude': -118.243425}]},
#  {'name': 'Mindbox',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.050907,
#     'longitude': -118.253254}]},
#  {'name': 'Brilliant2',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.043228,
#     'longitude': -118.46856}]},
#  {'name': 'Davinci Selectwork',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 33.9772881,
#     'longitude': -118.4258761}]},
#  {'name': 'Shopflick',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.044939,
#     'longitude': -118.419067}]},
#  {'name': 'Mojiva',
#   'offices': [{'city': 'New York',
#     'latitude': 40.7185614,
#     'longitude': -73.998662},
#    {'city': 'San Francisco', 'latitude': None, 'longitude': None},
#    {'city': 'London', 'latitude': None, 'longitude': None},
#    {'city': 'Seattle', 'latitude': None, 'longitude': None},
#    {'city': 'Los Angeles', 'latitude': None, 'longitude': None},
#    {'city': 'Chicago', 'latitude': None, 'longitude': None}]},
#  {'name': 'UnitedLayer',
#   'offices': [{'city': 'San Francisco',
#     'latitude': 37.724999,
#     'longitude': -122.397254},
#    {'city': 'Los Angeles', 'latitude': None, 'longitude': None}]},
#  {'name': 'BizRate',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.031646,
#     'longitude': -118.455352}]},
#  {'name': 'Modern Feed',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.085749,
#     'longitude': -118.343791}]},
#  {'name': 'Channel M',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.052187,
#     'longitude': -118.243425}]},
#  {'name': 'FreedomSpeaks',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.0634,
#     'longitude': -118.445257}]},
#  {'name': 'Schematic',
#   'offices': [{'city': 'New York', 'latitude': None, 'longitude': None},
#    {'city': 'Los Angeles', 'latitude': None, 'longitude': None}]},
#  {'name': 'GeoGraffiti',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.05285,
#     'longitude': -118.264858}]},
#  {'name': 'The Yucaipa Companies',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.0905865,
#     'longitude': -118.3905856}]},
#  {'name': 'OVGuide',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.052187,
#     'longitude': -118.243425}]},
#  {'name': 'FirstString',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.052187,
#     'longitude': -118.243425}]},
#  {'name': 'The Economist Group',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.080651,
#     'longitude': -118.334436}]},
#  {'name': 'Passenger',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.029956,
#     'longitude': -118.308943},
#    {'city': 'New York', 'latitude': None, 'longitude': None}]},
#  {'name': 'TrafficZ',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.037542,
#     'longitude': -118.441178}]},
#  {'name': 'SocialVibe',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.0815238,
#     'longitude': -118.3826743}]},
#  {'name': 'LiveAutographs',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.052187,
#     'longitude': -118.243425}]},
#  {'name': 'VersaTables',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 33.903544,
#     'longitude': -118.265655}]},
#  {'name': 'GameFly',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 33.934558,
#     'longitude': -118.3962622}]},
#  {'name': 'Zap2it',
#   'offices': [{'city': 'Chicago',
#     'latitude': 41.876499,
#     'longitude': -87.624179},
#    {'city': 'Los Angeles', 'latitude': None, 'longitude': None}]},
#  {'name': 'Jamba',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.052187,
#     'longitude': -118.243425}]},
#  {'name': 'Placebase',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.044931,
#     'longitude': -118.23497}]},
#  {'name': 'Fabric Interactive',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.0748,
#     'longitude': -118.288536}]},
#  {'name': 'MeDeploy',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.1395597,
#     'longitude': -118.3870991}]},
#  {'name': 'Interpolls',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.048573,
#     'longitude': -118.25957},
#    {'city': 'New York', 'latitude': 40.7534549, 'longitude': -73.9724886}]},
#  {'name': 'appssavvy',
#   'offices': [{'city': 'New York',
#     'latitude': 40.724604,
#     'longitude': -73.996876},
#    {'city': 'Chicago', 'latitude': None, 'longitude': None},
#    {'city': 'Los Angeles', 'latitude': None, 'longitude': None},
#    {'city': 'San Francisco', 'latitude': None, 'longitude': None}]},
#  {'name': 'ShopIt',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.05304,
#     'longitude': -118.46643}]},
#  {'name': 'simple season',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.039585,
#     'longitude': -118.255804}]},
#  {'name': 'Attention Span Media',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.06226,
#     'longitude': -118.343648}]},
#  {'name': 'College Tonight',
#   'offices': [{'city': 'Los Angeles', 'latitude': None, 'longitude': None}]},
#  {'name': 'Fandango',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.031646,
#     'longitude': -118.455352}]},
#  {'name': 'Break Media',
#   'offices': [{'city': 'Los Angeles', 'latitude': None, 'longitude': None}]},
#  {'name': 'Genius Labs',
#   'offices': [{'city': 'Los Angeles', 'latitude': None, 'longitude': None}]},
#  {'name': 'ZipcodeZ',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.05775,
#     'longitude': -118.4138}]},
#  {'name': 'SceneCaster',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.052187,
#     'longitude': -118.243425}]},
#  {'name': 'J2 Global Communications',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.1015548,
#     'longitude': -118.3406957}]},
#  {'name': 'Rootdown',
#   'offices': [{'city': 'Red Bank',
#     'latitude': 40.356745,
#     'longitude': -74.075105},
#    {'city': 'Los Angeles', 'latitude': 34.048545, 'longitude': -118.339502}]},
#  {'name': 'Samfind',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.052107,
#     'longitude': -118.385271}]},
#  {'name': 'MySpace Music',
#   'offices': [{'city': 'Beverly Hills', 'latitude': None, 'longitude': None},
#    {'city': 'Los Angeles', 'latitude': None, 'longitude': None}]},
#  {'name': 'Event Innovation',
#   'offices': [{'city': 'Herndon',
#     'latitude': 38.903379,
#     'longitude': -77.040727},
#    {'city': '25th Floor', 'latitude': None, 'longitude': None},
#    {'city': 'Los Angeles', 'latitude': 34.061368, 'longitude': -118.416334},
#    {'city': 'Sydney', 'latitude': -33.866, 'longitude': 151.212159},
#    {'city': 'London', 'latitude': 51.516203, 'longitude': -0.133591}]},
#  {'name': 'Icebox',
#   'offices': [{'city': 'Los Angeles', 'latitude': None, 'longitude': None}]},
#  {'name': 'SDI Semiconductor Instruments',
#   'offices': [{'city': 'Naples',
#     'latitude': 40.839997,
#     'longitude': 14.252871},
#    {'city': 'Trim', 'latitude': 53.554327, 'longitude': -6.795441},
#    {'city': 'Los Angeles', 'latitude': 34.052187, 'longitude': -118.243425}]},
#  {'name': 'CraveOnline',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 33.987978,
#     'longitude': -118.362442},
#    {'city': 'New York', 'latitude': None, 'longitude': None},
#    {'city': 'Chicago', 'latitude': None, 'longitude': None},
#    {'city': 'Scottsdale', 'latitude': None, 'longitude': None},
#    {'city': 'San Francisco', 'latitude': None, 'longitude': None}]},
#  {'name': 'GoodSearch',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.086348,
#     'longitude': -118.488226}]},
#  {'name': 'Tubefilter',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.070436,
#     'longitude': -118.350486}]},
#  {'name': 'Skwibble',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.052187,
#     'longitude': -118.243425}]},
#  {'name': 'magnify360',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 33.946285,
#     'longitude': -118.38823}]},
#  {'name': 'ReddiNet',
#   'offices': [{'city': 'Los Angeles', 'latitude': None, 'longitude': None}]},
#  {'name': 'MESoft',
#   'offices': [{'city': 'Los Angeles', 'latitude': None, 'longitude': None}]},
#  {'name': 'Quant the News',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.054259,
#     'longitude': -118.414064}]},
#  {'name': 'SiteRapture',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.062262,
#     'longitude': -118.348198}]},
#  {'name': 'Weblocal',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.052187,
#     'longitude': -118.243425},
#    {'city': 'Montreal', 'latitude': 45.545447, 'longitude': -73.639076}]},
#  {'name': 'BakeSpace',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.098028,
#     'longitude': -118.353624}]},
#  {'name': 'Geodelic Systems',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.005914,
#     'longitude': -118.488129}]},
#  {'name': 'eVoice',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.101555,
#     'longitude': -118.340696}]},
#  {'name': 'Tubefilter',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.070436,
#     'longitude': -118.350486}]},
#  {'name': 'Skwibble',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.052187,
#     'longitude': -118.243425}]},
#  {'name': 'magnify360',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 33.946285,
#     'longitude': -118.38823}]},
#  {'name': 'ReddiNet',
#   'offices': [{'city': 'Los Angeles', 'latitude': None, 'longitude': None}]},
#  {'name': 'MESoft',
#   'offices': [{'city': 'Los Angeles', 'latitude': None, 'longitude': None}]},
#  {'name': 'Quant the News',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.054259,
#     'longitude': -118.414064}]},
#  {'name': 'SiteRapture',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.062262,
#     'longitude': -118.348198}]},
#  {'name': 'Weblocal',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.052187,
#     'longitude': -118.243425},
#    {'city': 'Montreal', 'latitude': 45.545447, 'longitude': -73.639076}]},
#  {'name': 'BakeSpace',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.098028,
#     'longitude': -118.353624}]},
#  {'name': 'Geodelic Systems',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.005914,
#     'longitude': -118.488129}]},
#  {'name': 'eVoice',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.101555,
#     'longitude': -118.340696}]},
#  {'name': 'PeopleJar',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.1030032,
#     'longitude': -118.4104684}]},
#  {'name': 'Hollywood Interactive Group',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.052187,
#     'longitude': -118.243425}]},
#  {'name': 'Ratchet',
#   'offices': [{'city': 'Minneapolis',
#     'latitude': 44.989126,
#     'longitude': -93.278663},
#    {'city': 'Chicago', 'latitude': 41.890441, 'longitude': -87.629377},
#    {'city': 'Los Angeles', 'latitude': 33.810534, 'longitude': -118.109206}]},
#  {'name': 'NOTCOT',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.052187,
#     'longitude': -118.243425}]},
#  {'name': 'Total Immersion',
#   'offices': [{'city': 'Suresnes',
#     'latitude': 48.872989,
#     'longitude': 2.230086},
#    {'city': 'Los Angeles', 'latitude': 34.062164, 'longitude': -118.358787}]},
#  {'name': 'FanPrice',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 38.233786,
#     'longitude': -122.636071}]},
#  {'name': 'SportsGenie',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.0522,
#     'longitude': -118.2429}]},
#  {'name': '6s Marketing',
#   'offices': [{'city': 'Vancouver', 'latitude': None, 'longitude': None},
#    {'city': 'Toronto', 'latitude': None, 'longitude': None},
#    {'city': 'New York', 'latitude': None, 'longitude': None},
#    {'city': 'Los Angeles', 'latitude': None, 'longitude': None},
#    {'city': 'San Francisco', 'latitude': None, 'longitude': None}]},
#  {'name': 'Creative Kingdom Animation Studios Film',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.0541081,
#     'longitude': -118.2595569}]},
#  {'name': 'Sceneclips',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.05438,
#     'longitude': -118.26728}]},
#  {'name': 'Mybandstock',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 42.2802675,
#     'longitude': -83.7420579}]},
#  {'name': 'Xtreme Widgets',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 33.988687,
#     'longitude': -118.439532}]},
#  {'name': 'TVGla',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 33.988687,
#     'longitude': -118.439532}]},
#  {'name': 'MyFreeImplants',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.087825,
#     'longitude': -118.379493}]},
#  {'name': 'booksRhere',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.024817,
#     'longitude': -118.295117}]},
#  {'name': 'Auditude',
#   'offices': [{'city': 'Palo Alto', 'latitude': None, 'longitude': None},
#    {'city': 'New York', 'latitude': None, 'longitude': None},
#    {'city': 'Los Angeles', 'latitude': None, 'longitude': None}]},
#  {'name': 'The DigiTrust Group',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 33.946126,
#     'longitude': -118.382385}]},
#  {'name': 'kidthing',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.045845,
#     'longitude': -118.237811},
#    {'city': 'Mason', 'latitude': 39.360128, 'longitude': -84.308653}]},
#  {'name': 'GetBack',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.0342337,
#     'longitude': -118.4536137}]},
#  {'name': 'Vitality',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.0485243,
#     'longitude': -118.4623627}]},
#  {'name': 'International Creative Management',
#   'offices': [{'city': 'Los Angeles', 'latitude': None, 'longitude': None}]},
#  {'name': 'Ferrazzi Greenlight',
#   'offices': [{'city': 'Los Angeles', 'latitude': None, 'longitude': None}]},
#  {'name': 'PlayerAuctions',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.052187,
#     'longitude': -118.243425}]},
#  {'name': 'A Unique Presentation',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.025386,
#     'longitude': -118.401729}]},
#  {'name': 'MovieFlix',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.070146,
#     'longitude': -118.365526}]},
#  {'name': 'Wild Brain',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.064286,
#     'longitude': -118.372638}]},
#  {'name': 'Saltlick Labs',
#   'offices': [{'city': 'Austin',
#     'latitude': 30.4156188,
#     'longitude': -97.8014482},
#    {'city': 'Sydney', 'latitude': -33.867139, 'longitude': 151.207114},
#    {'city': 'Los Angeles', 'latitude': 34.052187, 'longitude': -118.243425}]},
#  {'name': 'Launch 10',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.054356,
#     'longitude': -118.422696}]},
#  {'name': 'ConstructionDeal',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.052187,
#     'longitude': -118.243425}]},
#  {'name': 'PlaceVine',
#   'offices': [{'city': 'New York',
#     'latitude': 40.756054,
#     'longitude': -73.986951},
#    {'city': 'Los Angeles', 'latitude': 34.052187, 'longitude': -118.243425}]},
#  {'name': 'Tadlock Enterprises',
#   'offices': [{'city': 'Los Angeles', 'latitude': None, 'longitude': None},
#    {'city': 'Seattle', 'latitude': None, 'longitude': None}]},
#  {'name': 'Txtms',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.052187,
#     'longitude': -118.243425}]},
#  {'name': 'Zumbox',
#   'offices': [{'city': 'Los Angeles', 'latitude': None, 'longitude': None}]},
#  {'name': 'CrownPeak',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.0240159,
#     'longitude': -118.3767176}]},
#  {'name': 'Liferay',
#   'offices': [{'city': 'Los Angeles', 'latitude': None, 'longitude': None}]},
#  {'name': 'Adexa',
#   'offices': [{'city': 'Los Angeles', 'latitude': None, 'longitude': None}]},
#  {'name': 'Awareness Technologies',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 33.9812355,
#     'longitude': -118.44097}]},
#  {'name': 'Fonality',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 33.9874429,
#     'longitude': -118.3846632}]},
#  {'name': 'GoGo Lingo',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.052187,
#     'longitude': -118.243425}]},
#  {'name': 'Creative Artists Agency',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.0586832,
#     'longitude': -118.4158174}]},
#  {'name': 'Table For Six',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.058324,
#     'longitude': -118.441888}]},
#  {'name': 'Zed',
#   'offices': [{'city': 'Las Rozas (Madrid)',
#     'latitude': None,
#     'longitude': None},
#    {'city': 'Redwood City', 'latitude': None, 'longitude': None},
#    {'city': 'Los Angeles', 'latitude': None, 'longitude': None},
#    {'city': 'Miami', 'latitude': None, 'longitude': None}]},
#  {'name': 'National Lampoon',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.0975446,
#     'longitude': -118.3685931}]},
#  {'name': 'Maas Global Solutions Corporation',
#   'offices': [{'city': 'Las Vegas',
#     'latitude': 36.1211955,
#     'longitude': -115.2429972},
#    {'city': 'Simi Valley', 'latitude': None, 'longitude': None},
#    {'city': 'Los Angeles', 'latitude': None, 'longitude': None},
#    {'city': 'Kansas City', 'latitude': None, 'longitude': None}]},
#  {'name': 'Sennari',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 33.9782287,
#     'longitude': -118.4303427},
#    {'city': 'Los Angeles',
#     'latitude': 33.9782287,
#     'longitude': -118.4303427}]},
#  {'name': 'Broken Knuckles Clothing',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.0760614,
#     'longitude': -118.3729534}]},
#  {'name': 'LeadPoint',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.054212,
#     'longitude': -118.464454},
#    {'city': 'London', 'latitude': 51.5177117, 'longitude': -0.1410218}]},
#  {'name': 'Equator',
#   'offices': [{'city': 'Los Angeles', 'latitude': None, 'longitude': None}]},
#  {'name': 'Univision',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 33.9778907,
#     'longitude': -118.3925179}]},
#  {'name': 'ReferQuest',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.031222,
#     'longitude': -118.420346}]},
#  {'name': 'Trustworthy',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.049246,
#     'longitude': -118.395346}]},
#  {'name': 'KlickSports',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.0431973,
#     'longitude': -118.445584}]},
#  {'name': 'Boom Studios',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.060523,
#     'longitude': -118.367703}]},
#  {'name': 'Link Gateway',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.052187,
#     'longitude': -118.243425}]},
#  {'name': 'TechForward',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.146503,
#     'longitude': -118.613385}]},
#  {'name': 'Mobile Messenger',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 33.979956,
#     'longitude': -118.393979}]},
#  {'name': 'ABCO TECHNOLOGY',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 33.978825,
#     'longitude': -118.394889}]},
#  {'name': 'GaimTheory',
#   'offices': [{'city': 'Los Angeles', 'latitude': None, 'longitude': None}]},
#  {'name': 'eModeration',
#   'offices': [{'city': 'London',
#     'latitude': 51.5195795,
#     'longitude': -0.1065551},
#    {'city': 'New York', 'latitude': None, 'longitude': None},
#    {'city': 'Los Angeles',
#     'latitude': 34.1538216,
#     'longitude': -118.4662511}]},
#  {'name': "Blip'd",
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.0760614,
#     'longitude': -118.3729534}]},
#  {'name': 'Jobspring Partners',
#   'offices': [{'city': 'Arlington',
#     'latitude': 38.883107,
#     'longitude': -77.115586},
#    {'city': 'Boston', 'latitude': 42.3505124, 'longitude': -71.0757952},
#    {'city': 'Chicago', 'latitude': 41.881607, 'longitude': -87.632735},
#    {'city': 'Los Angeles', 'latitude': 34.057346, 'longitude': -118.447078},
#    {'city': 'New York', 'latitude': None, 'longitude': None},
#    {'city': 'Newport Beach', 'latitude': 33.670397, 'longitude': -117.862158},
#    {'city': 'Philadelphia', 'latitude': 39.9542837, 'longitude': -75.1664957},
#    {'city': 'San Francisco', 'latitude': 37.788653, 'longitude': -122.401333},
#    {'city': 'San Jose', 'latitude': None, 'longitude': None}]},
#  {'name': 'Workbridge Associates',
#   'offices': [{'city': 'Arlington',
#     'latitude': 38.883297,
#     'longitude': -77.116897},
#    {'city': 'Atlanta', 'latitude': 33.9332549, 'longitude': -84.3528697},
#    {'city': 'Boston', 'latitude': 42.3505124, 'longitude': -71.0757952},
#    {'city': 'Chicago', 'latitude': 41.881607, 'longitude': -87.632735},
#    {'city': 'Los Angeles', 'latitude': 34.057346, 'longitude': -118.447078},
#    {'city': 'New York', 'latitude': 40.7543489, 'longitude': -73.9789451},
#    {'city': 'Newport Beach', 'latitude': 33.669758, 'longitude': -117.862093},
#    {'city': 'Philadelphia', 'latitude': 39.9528012, 'longitude': -75.1668626},
#    {'city': 'San Francisco', 'latitude': 37.789778, 'longitude': -122.401736},
#    {'city': 'San Jose', 'latitude': 37.334596, 'longitude': -121.89291}]},
#  {'name': 'Grindr',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.11275,
#     'longitude': -118.386224}]},
#  {'name': 'Ranker',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.1012181,
#     'longitude': -118.325739}]},
#  {'name': 'Epsilon Concepts',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.051508,
#     'longitude': -118.262233}]},
#  {'name': 'Here Media',
#   'offices': [{'city': 'Los Angeles', 'latitude': None, 'longitude': None},
#    {'city': 'New York', 'latitude': None, 'longitude': None}]},
#  {'name': 'Silvatar Media',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.1036353,
#     'longitude': -118.293316}]},
#  {'name': 'Global Digital Media Xchange',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 33.943108,
#     'longitude': -118.374904}]},
#  {'name': 'BrandBucket',
#   'offices': [{'city': 'Los Angeles', 'latitude': None, 'longitude': None}]},
#  {'name': 'Sensis',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.0490571,
#     'longitude': -118.2593181},
#    {'city': 'Washington', 'latitude': 38.916733, 'longitude': -77.037614}]},
#  {'name': 'Fed Receiver',
#   'offices': [{'city': 'Los Angeles', 'latitude': None, 'longitude': None}]},
#  {'name': 'Huge',
#   'offices': [{'city': 'Brooklyn',
#     'latitude': 40.7028474,
#     'longitude': -73.9906813},
#    {'city': 'Los Angeles', 'latitude': 34.167304, 'longitude': -118.373614},
#    {'city': 'London', 'latitude': 51.4920878, 'longitude': -0.1652217},
#    {'city': 'Singapore', 'latitude': None, 'longitude': None},
#    {'city': 'Rio de Janeiro, RJ', 'latitude': None, 'longitude': None},
#    {'city': 'Atlanta', 'latitude': None, 'longitude': None},
#    {'city': 'San Francisco', 'latitude': None, 'longitude': None},
#    {'city': 'Portland', 'latitude': None, 'longitude': None},
#    {'city': 'Washington', 'latitude': None, 'longitude': None},
#    {'city': 'Atlanta', 'latitude': None, 'longitude': None}]},
#  {'name': 'HauteLook',
#   'offices': [{'city': 'Los Angeles', 'latitude': None, 'longitude': None}]},
#  {'name': 'Velti',
#   'offices': [{'city': 'London', 'latitude': None, 'longitude': None},
#    {'city': 'San Francisco', 'latitude': None, 'longitude': None},
#    {'city': 'New York', 'latitude': None, 'longitude': None},
#    {'city': 'Marousi', 'latitude': None, 'longitude': None},
#    {'city': 'Paris', 'latitude': None, 'longitude': None},
#    {'city': 'Moscow', 'latitude': None, 'longitude': None},
#    {'city': 'Sofia', 'latitude': None, 'longitude': None},
#    {'city': 'Beijing', 'latitude': None, 'longitude': None},
#    {'city': 'Mumbai', 'latitude': None, 'longitude': None},
#    {'city': 'Nicosia', 'latitude': None, 'longitude': None},
#    {'city': 'Dublin', 'latitude': None, 'longitude': None},
#    {'city': 'Los Angeles', 'latitude': None, 'longitude': None},
#    {'city': 'Shanghai', 'latitude': None, 'longitude': None},
#    {'city': 'DÃ¼sseldorf', 'latitude': None, 'longitude': None},
#    {'city': 'Pozuelo de Alarcon', 'latitude': None, 'longitude': None}]},
#  {'name': 'Daimer Industries',
#   'offices': [{'city': 'Woburn',
#     'latitude': 42.499146,
#     'longitude': -71.1253375},
#    {'city': 'New York', 'latitude': None, 'longitude': None},
#    {'city': 'Los Angeles', 'latitude': None, 'longitude': None},
#    {'city': 'Houston', 'latitude': None, 'longitude': None},
#    {'city': 'Dallas,', 'latitude': None, 'longitude': None},
#    {'city': 'Chicago', 'latitude': None, 'longitude': None},
#    {'city': 'Phoenix', 'latitude': None, 'longitude': None},
#    {'city': 'San Francisco, CA', 'latitude': None, 'longitude': None},
#    {'city': 'San Diego', 'latitude': None, 'longitude': None},
#    {'city': 'Miami', 'latitude': None, 'longitude': None},
#    {'city': 'Las Vegas', 'latitude': None, 'longitude': None},
#    {'city': 'Philadelphia', 'latitude': None, 'longitude': None},
#    {'city': 'Denver', 'latitude': None, 'longitude': None}]},
#  {'name': 'Yoostar',
#   'offices': [{'city': 'New York',
#     'latitude': 40.756054,
#     'longitude': -73.986951},
#    {'city': 'Los Angeles', 'latitude': 34.052187, 'longitude': -118.243425}]},
#  {'name': 'WebPurify',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.052187,
#     'longitude': -118.243425}]},
#  {'name': 'eblizz',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.0163012,
#     'longitude': -118.4920896}]},
#  {'name': 'SchoolRack',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.0386656,
#     'longitude': -118.4221519}]},
#  {'name': 'Painless Productions',
#   'offices': [{'city': 'Los Angeles', 'latitude': None, 'longitude': None}]},
#  {'name': 'Cocodot',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.104692,
#     'longitude': -118.375698}]},
#  {'name': 'Duane Morris LLP',
#   'offices': [{'city': 'Philadelphia', 'latitude': None, 'longitude': None},
#    {'city': 'Atlanta', 'latitude': None, 'longitude': None},
#    {'city': 'Baltimore', 'latitude': None, 'longitude': None},
#    {'city': 'Boca Raton', 'latitude': None, 'longitude': None},
#    {'city': 'Boston', 'latitude': None, 'longitude': None},
#    {'city': 'Cherry Hill', 'latitude': None, 'longitude': None},
#    {'city': 'Chicago', 'latitude': None, 'longitude': None},
#    {'city': 'Hoan Kiem District, Hanoi', 'latitude': None, 'longitude': None},
#    {'city': 'District 1, Ho Chi Minh City',
#     'latitude': None,
#     'longitude': None},
#    {'city': 'Houston', 'latitude': None, 'longitude': None},
#    {'city': 'Truckee', 'latitude': None, 'longitude': None},
#    {'city': 'Las Vegas', 'latitude': None, 'longitude': None},
#    {'city': 'London', 'latitude': None, 'longitude': None},
#    {'city': 'Los Angeles', 'latitude': None, 'longitude': None},
#    {'city': 'Miami', 'latitude': None, 'longitude': None},
#    {'city': 'New York', 'latitude': None, 'longitude': None},
#    {'city': 'Newark', 'latitude': None, 'longitude': None},
#    {'city': 'Pittsburgh', 'latitude': None, 'longitude': None},
#    {'city': 'Princeton', 'latitude': None, 'longitude': None},
#    {'city': 'San Diego', 'latitude': None, 'longitude': None},
#    {'city': 'San Francisco', 'latitude': None, 'longitude': None},
#    {'city': 'Singapore', 'latitude': None, 'longitude': None},
#    {'city': 'Washington', 'latitude': None, 'longitude': None},
#    {'city': 'Wilmington', 'latitude': None, 'longitude': None}]},
#  {'name': 'Brierley+Partners',
#   'offices': [{'city': 'Los Angeles', 'latitude': None, 'longitude': None}]},
#  {'name': 'Moviepilot',
#   'offices': [{'city': 'Berlin',
#     'latitude': 52.4947266,
#     'longitude': 13.398504},
#    {'city': 'Los Angeles',
#     'latitude': 34.0522342,
#     'longitude': -118.2436849}]},
#  {'name': 'High Density Networks',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.058101,
#     'longitude': -118.235338}]},
#  {'name': 'ITTAGS',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.052187,
#     'longitude': -118.243425}]},
#  {'name': 'Iteego',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.052187,
#     'longitude': -118.243425},
#    {'city': 'Gothenburg', 'latitude': None, 'longitude': None}]},
#  {'name': 'Global Fitness Media',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.054318,
#     'longitude': -118.462876}]},
#  {'name': 'Zugara',
#   'offices': [{'city': 'Los Angeles', 'latitude': None, 'longitude': None}]},
#  {'name': 'CallFire',
#   'offices': [{'city': 'Los Angeles', 'latitude': None, 'longitude': None},
#    {'city': 'Santa Monica', 'latitude': None, 'longitude': None}]},
#  {'name': 'AECOM Technology',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.0507962,
#     'longitude': -118.2568615}]},
#  {'name': 'Hythiam',
#   'offices': [{'city': 'Los Angeles', 'latitude': None, 'longitude': None}]},
#  {'name': 'University of Southern California',
#   'offices': [{'city': 'Los Angeles', 'latitude': None, 'longitude': None}]},
#  {'name': 'DTT',
#   'offices': [{'city': 'Los Angeles', 'latitude': None, 'longitude': None}]},
#  {'name': 'Culture Jam',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.0137151,
#     'longitude': -118.4660597}]},
#  {'name': 'California 7 Studios',
#   'offices': [{'city': 'Los Angeles', 'latitude': None, 'longitude': None}]},
#  {'name': 'Pipit Interactive',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.045499,
#     'longitude': -118.47036}]},
#  {'name': 'Top Rated Website Designers',
#   'offices': [{'city': 'Carlsbad',
#     'latitude': 33.1412124,
#     'longitude': -117.3205123},
#    {'city': 'Los Angeles', 'latitude': 33.9933257, 'longitude': -118.3987842},
#    {'city': 'San Diego', 'latitude': 33.1412124, 'longitude': -117.3205123}]},
#  {'name': 'SOA Software',
#   'offices': [{'city': 'Los Angeles', 'latitude': None, 'longitude': None}]},
#  {'name': 'IVR Technologies',
#   'offices': [{'city': 'Los Angeles',
#     'latitude': 34.050066,
#     'longitude': -118.253161}]}]

# %%
LosAngeles[0]["offices"]
# Out:
# [{'city': 'Los Angeles', 'latitude': 34.057498, 'longitude': -118.446596}]

# %%
LosAngeles_new = []
for i in LosAngeles:
    for j in i['offices']:
        if j['city'] == 'Los Angeles':
            city = j['city']
            lat = j['latitude']
            lon = j['longitude']
            name = i['name']
            type_ = ({"typepoint": 
                      {"type": "Point", 
                         "coordinates": [j['latitude'], j['longitude']]}})
            
            LosAngeles_new.append({"name":name, "lat":lat, "long":lon, "type":type_})
LosAngeles_new
# Out:
# [{'name': 'Helio',
#   'lat': 34.057498,
#   'long': -118.446596,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.057498, -118.446596]}}},
#  {'name': 'Stickam',
#   'lat': 34.051409,
#   'long': -118.254558,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.051409, -118.254558]}}},
#  {'name': 'Ustream',
#   'lat': None,
#   'long': None,
#   'type': {'typepoint': {'type': 'Point', 'coordinates': [None, None]}}},
#  {'name': 'TripUp',
#   'lat': 34.052187,
#   'long': -118.243425,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.052187, -118.243425]}}},
#  {'name': 'Eventful',
#   'lat': None,
#   'long': None,
#   'type': {'typepoint': {'type': 'Point', 'coordinates': [None, None]}}},
#  {'name': 'ScanScout',
#   'lat': 34.050887,
#   'long': -118.459995,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.050887, -118.459995]}}},
#  {'name': 'WebbAlert',
#   'lat': 34.052187,
#   'long': -118.243425,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.052187, -118.243425]}}},
#  {'name': 'Revver',
#   'lat': 34.052187,
#   'long': -118.243425,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.052187, -118.243425]}}},
#  {'name': 'Social Platform',
#   'lat': 34.101617,
#   'long': -118.327071,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.101617, -118.327071]}}},
#  {'name': 'SuicideGirls',
#   'lat': 34.062262,
#   'long': -118.348198,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.062262, -118.348198]}}},
#  {'name': 'DAVE Networks',
#   'lat': 33.979033,
#   'long': -118.423423,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [33.979033, -118.423423]}}},
#  {'name': 'Shopzilla',
#   'lat': 37.09024,
#   'long': -95.712891,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [37.09024, -95.712891]}}},
#  {'name': 'PriceGrabber',
#   'lat': 37.09024,
#   'long': -95.712891,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [37.09024, -95.712891]}}},
#  {'name': 'hulu',
#   'lat': 34.031276,
#   'long': -118.456806,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.031276, -118.456806]}}},
#  {'name': 'ElephantDrive',
#   'lat': None,
#   'long': None,
#   'type': {'typepoint': {'type': 'Point', 'coordinates': [None, None]}}},
#  {'name': 'Musicshake',
#   'lat': None,
#   'long': None,
#   'type': {'typepoint': {'type': 'Point', 'coordinates': [None, None]}}},
#  {'name': 'Orgoo',
#   'lat': 34.0481711,
#   'long': -118.4419012,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.0481711, -118.4419012]}}},
#  {'name': 'RotoHog',
#   'lat': 33.959799,
#   'long': -118.343938,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [33.959799, -118.343938]}}},
#  {'name': 'mEgo',
#   'lat': 34.064491,
#   'long': -118.42749,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.064491, -118.42749]}}},
#  {'name': 'StreetFire',
#   'lat': 33.982431,
#   'long': -118.426707,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [33.982431, -118.426707]}}},
#  {'name': 'Turn',
#   'lat': None,
#   'long': None,
#   'type': {'typepoint': {'type': 'Point', 'coordinates': [None, None]}}},
#  {'name': 'Springbox',
#   'lat': 34.0065488,
#   'long': -118.3923578,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.0065488, -118.3923578]}}},
#  {'name': 'Seethroo',
#   'lat': None,
#   'long': None,
#   'type': {'typepoint': {'type': 'Point', 'coordinates': [None, None]}}},
#  {'name': 'RazorGator',
#   'lat': 34.047312,
#   'long': -118.445243,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.047312, -118.445243]}}},
#  {'name': 'Oversee',
#   'lat': 34.051368,
#   'long': -118.256305,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.051368, -118.256305]}}},
#  {'name': 'Zynga',
#   'lat': None,
#   'long': None,
#   'type': {'typepoint': {'type': 'Point', 'coordinates': [None, None]}}},
#  {'name': 'MetaNotes',
#   'lat': 34.128046,
#   'long': -118.289065,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.128046, -118.289065]}}},
#  {'name': 'PlanJam',
#   'lat': 34.059721,
#   'long': -118.425401,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.059721, -118.425401]}}},
#  {'name': 'E! Entertainment',
#   'lat': 34.062253,
#   'long': -118.3543243,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.062253, -118.3543243]}}},
#  {'name': 'Jirbo',
#   'lat': 34.064629,
#   'long': -118.469316,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.064629, -118.469316]}}},
#  {'name': 'Gorilla Nation Media',
#   'lat': 33.988735,
#   'long': -118.368871,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [33.988735, -118.368871]}}},
#  {'name': 'Social Gaming Network',
#   'lat': 37.446823,
#   'long': -122.161523,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [37.446823, -122.161523]}}},
#  {'name': 'Los Angeles Times Media Group',
#   'lat': None,
#   'long': None,
#   'type': {'typepoint': {'type': 'Point', 'coordinates': [None, None]}}},
#  {'name': 'ePillager',
#   'lat': 34.029209,
#   'long': -118.289344,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.029209, -118.289344]}}},
#  {'name': 'JuicyCampus',
#   'lat': 33.954874,
#   'long': -118.396507,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [33.954874, -118.396507]}}},
#  {'name': 'ALi Corporation',
#   'lat': 34.0618146,
#   'long': -118.2899533,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.0618146, -118.2899533]}}},
#  {'name': 'Napster',
#   'lat': 34.080772,
#   'long': -118.3891962,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.080772, -118.3891962]}}},
#  {'name': 'AtomicOnline',
#   'lat': 33.988735,
#   'long': -118.368871,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [33.988735, -118.368871]}}},
#  {'name': 'SEO Intelligence',
#   'lat': 34.041037,
#   'long': -118.23341,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.041037, -118.23341]}}},
#  {'name': 'Taltopia',
#   'lat': 34.052187,
#   'long': -118.243425,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.052187, -118.243425]}}},
#  {'name': 'SmartRatings',
#   'lat': 34.047104,
#   'long': -118.434213,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.047104, -118.434213]}}},
#  {'name': 'DailyStrength',
#   'lat': 34.043948,
#   'long': -118.468204,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.043948, -118.468204]}}},
#  {'name': 'CrewedUp',
#   'lat': 34.089679,
#   'long': -118.292618,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.089679, -118.292618]}}},
#  {'name': 'Authenticlick',
#   'lat': 34.062504,
#   'long': -118.354605,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.062504, -118.354605]}}},
#  {'name': 'PeopleSupport',
#   'lat': None,
#   'long': None,
#   'type': {'typepoint': {'type': 'Point', 'coordinates': [None, None]}}},
#  {'name': 'FASTALLEY',
#   'lat': 34.081952,
#   'long': -118.357658,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.081952, -118.357658]}}},
#  {'name': 'Wedding Channel',
#   'lat': 34.0486806,
#   'long': -118.2587784,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.0486806, -118.2587784]}}},
#  {'name': 'Causecast',
#   'lat': 34.018349,
#   'long': -118.486889,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.018349, -118.486889]}}},
#  {'name': 'iCrossing',
#   'lat': None,
#   'long': None,
#   'type': {'typepoint': {'type': 'Point', 'coordinates': [None, None]}}},
#  {'name': 'Magento',
#   'lat': 34.052187,
#   'long': -118.243425,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.052187, -118.243425]}}},
#  {'name': 'Mindbox',
#   'lat': 34.050907,
#   'long': -118.253254,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.050907, -118.253254]}}},
#  {'name': 'Brilliant2',
#   'lat': 34.043228,
#   'long': -118.46856,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.043228, -118.46856]}}},
#  {'name': 'Davinci Selectwork',
#   'lat': 33.9772881,
#   'long': -118.4258761,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [33.9772881, -118.4258761]}}},
#  {'name': 'Shopflick',
#   'lat': 34.044939,
#   'long': -118.419067,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.044939, -118.419067]}}},
#  {'name': 'Mojiva',
#   'lat': None,
#   'long': None,
#   'type': {'typepoint': {'type': 'Point', 'coordinates': [None, None]}}},
#  {'name': 'UnitedLayer',
#   'lat': None,
#   'long': None,
#   'type': {'typepoint': {'type': 'Point', 'coordinates': [None, None]}}},
#  {'name': 'BizRate',
#   'lat': 34.031646,
#   'long': -118.455352,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.031646, -118.455352]}}},
#  {'name': 'Modern Feed',
#   'lat': 34.085749,
#   'long': -118.343791,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.085749, -118.343791]}}},
#  {'name': 'Channel M',
#   'lat': 34.052187,
#   'long': -118.243425,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.052187, -118.243425]}}},
#  {'name': 'FreedomSpeaks',
#   'lat': 34.0634,
#   'long': -118.445257,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.0634, -118.445257]}}},
#  {'name': 'Schematic',
#   'lat': None,
#   'long': None,
#   'type': {'typepoint': {'type': 'Point', 'coordinates': [None, None]}}},
#  {'name': 'GeoGraffiti',
#   'lat': 34.05285,
#   'long': -118.264858,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.05285, -118.264858]}}},
#  {'name': 'The Yucaipa Companies',
#   'lat': 34.0905865,
#   'long': -118.3905856,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.0905865, -118.3905856]}}},
#  {'name': 'OVGuide',
#   'lat': 34.052187,
#   'long': -118.243425,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.052187, -118.243425]}}},
#  {'name': 'FirstString',
#   'lat': 34.052187,
#   'long': -118.243425,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.052187, -118.243425]}}},
#  {'name': 'The Economist Group',
#   'lat': 34.080651,
#   'long': -118.334436,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.080651, -118.334436]}}},
#  {'name': 'Passenger',
#   'lat': 34.029956,
#   'long': -118.308943,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.029956, -118.308943]}}},
#  {'name': 'TrafficZ',
#   'lat': 34.037542,
#   'long': -118.441178,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.037542, -118.441178]}}},
#  {'name': 'SocialVibe',
#   'lat': 34.0815238,
#   'long': -118.3826743,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.0815238, -118.3826743]}}},
#  {'name': 'LiveAutographs',
#   'lat': 34.052187,
#   'long': -118.243425,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.052187, -118.243425]}}},
#  {'name': 'VersaTables',
#   'lat': 33.903544,
#   'long': -118.265655,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [33.903544, -118.265655]}}},
#  {'name': 'GameFly',
#   'lat': 33.934558,
#   'long': -118.3962622,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [33.934558, -118.3962622]}}},
#  {'name': 'Zap2it',
#   'lat': None,
#   'long': None,
#   'type': {'typepoint': {'type': 'Point', 'coordinates': [None, None]}}},
#  {'name': 'Jamba',
#   'lat': 34.052187,
#   'long': -118.243425,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.052187, -118.243425]}}},
#  {'name': 'Placebase',
#   'lat': 34.044931,
#   'long': -118.23497,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.044931, -118.23497]}}},
#  {'name': 'Fabric Interactive',
#   'lat': 34.0748,
#   'long': -118.288536,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.0748, -118.288536]}}},
#  {'name': 'MeDeploy',
#   'lat': 34.1395597,
#   'long': -118.3870991,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.1395597, -118.3870991]}}},
#  {'name': 'Interpolls',
#   'lat': 34.048573,
#   'long': -118.25957,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.048573, -118.25957]}}},
#  {'name': 'appssavvy',
#   'lat': None,
#   'long': None,
#   'type': {'typepoint': {'type': 'Point', 'coordinates': [None, None]}}},
#  {'name': 'ShopIt',
#   'lat': 34.05304,
#   'long': -118.46643,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.05304, -118.46643]}}},
#  {'name': 'simple season',
#   'lat': 34.039585,
#   'long': -118.255804,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.039585, -118.255804]}}},
#  {'name': 'Attention Span Media',
#   'lat': 34.06226,
#   'long': -118.343648,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.06226, -118.343648]}}},
#  {'name': 'College Tonight',
#   'lat': None,
#   'long': None,
#   'type': {'typepoint': {'type': 'Point', 'coordinates': [None, None]}}},
#  {'name': 'Fandango',
#   'lat': 34.031646,
#   'long': -118.455352,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.031646, -118.455352]}}},
#  {'name': 'Break Media',
#   'lat': None,
#   'long': None,
#   'type': {'typepoint': {'type': 'Point', 'coordinates': [None, None]}}},
#  {'name': 'Genius Labs',
#   'lat': None,
#   'long': None,
#   'type': {'typepoint': {'type': 'Point', 'coordinates': [None, None]}}},
#  {'name': 'ZipcodeZ',
#   'lat': 34.05775,
#   'long': -118.4138,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.05775, -118.4138]}}},
#  {'name': 'SceneCaster',
#   'lat': 34.052187,
#   'long': -118.243425,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.052187, -118.243425]}}},
#  {'name': 'J2 Global Communications',
#   'lat': 34.1015548,
#   'long': -118.3406957,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.1015548, -118.3406957]}}},
#  {'name': 'Rootdown',
#   'lat': 34.048545,
#   'long': -118.339502,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.048545, -118.339502]}}},
#  {'name': 'Samfind',
#   'lat': 34.052107,
#   'long': -118.385271,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.052107, -118.385271]}}},
#  {'name': 'MySpace Music',
#   'lat': None,
#   'long': None,
#   'type': {'typepoint': {'type': 'Point', 'coordinates': [None, None]}}},
#  {'name': 'Event Innovation',
#   'lat': 34.061368,
#   'long': -118.416334,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.061368, -118.416334]}}},
#  {'name': 'Icebox',
#   'lat': None,
#   'long': None,
#   'type': {'typepoint': {'type': 'Point', 'coordinates': [None, None]}}},
#  {'name': 'SDI Semiconductor Instruments',
#   'lat': 34.052187,
#   'long': -118.243425,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.052187, -118.243425]}}},
#  {'name': 'CraveOnline',
#   'lat': 33.987978,
#   'long': -118.362442,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [33.987978, -118.362442]}}},
#  {'name': 'GoodSearch',
#   'lat': 34.086348,
#   'long': -118.488226,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.086348, -118.488226]}}},
#  {'name': 'Tubefilter',
#   'lat': 34.070436,
#   'long': -118.350486,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.070436, -118.350486]}}},
#  {'name': 'Skwibble',
#   'lat': 34.052187,
#   'long': -118.243425,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.052187, -118.243425]}}},
#  {'name': 'magnify360',
#   'lat': 33.946285,
#   'long': -118.38823,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [33.946285, -118.38823]}}},
#  {'name': 'ReddiNet',
#   'lat': None,
#   'long': None,
#   'type': {'typepoint': {'type': 'Point', 'coordinates': [None, None]}}},
#  {'name': 'MESoft',
#   'lat': None,
#   'long': None,
#   'type': {'typepoint': {'type': 'Point', 'coordinates': [None, None]}}},
#  {'name': 'Quant the News',
#   'lat': 34.054259,
#   'long': -118.414064,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.054259, -118.414064]}}},
#  {'name': 'SiteRapture',
#   'lat': 34.062262,
#   'long': -118.348198,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.062262, -118.348198]}}},
#  {'name': 'Weblocal',
#   'lat': 34.052187,
#   'long': -118.243425,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.052187, -118.243425]}}},
#  {'name': 'BakeSpace',
#   'lat': 34.098028,
#   'long': -118.353624,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.098028, -118.353624]}}},
#  {'name': 'Geodelic Systems',
#   'lat': 34.005914,
#   'long': -118.488129,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.005914, -118.488129]}}},
#  {'name': 'eVoice',
#   'lat': 34.101555,
#   'long': -118.340696,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.101555, -118.340696]}}},
#  {'name': 'Tubefilter',
#   'lat': 34.070436,
#   'long': -118.350486,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.070436, -118.350486]}}},
#  {'name': 'Skwibble',
#   'lat': 34.052187,
#   'long': -118.243425,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.052187, -118.243425]}}},
#  {'name': 'magnify360',
#   'lat': 33.946285,
#   'long': -118.38823,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [33.946285, -118.38823]}}},
#  {'name': 'ReddiNet',
#   'lat': None,
#   'long': None,
#   'type': {'typepoint': {'type': 'Point', 'coordinates': [None, None]}}},
#  {'name': 'MESoft',
#   'lat': None,
#   'long': None,
#   'type': {'typepoint': {'type': 'Point', 'coordinates': [None, None]}}},
#  {'name': 'Quant the News',
#   'lat': 34.054259,
#   'long': -118.414064,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.054259, -118.414064]}}},
#  {'name': 'SiteRapture',
#   'lat': 34.062262,
#   'long': -118.348198,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.062262, -118.348198]}}},
#  {'name': 'Weblocal',
#   'lat': 34.052187,
#   'long': -118.243425,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.052187, -118.243425]}}},
#  {'name': 'BakeSpace',
#   'lat': 34.098028,
#   'long': -118.353624,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.098028, -118.353624]}}},
#  {'name': 'Geodelic Systems',
#   'lat': 34.005914,
#   'long': -118.488129,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.005914, -118.488129]}}},
#  {'name': 'eVoice',
#   'lat': 34.101555,
#   'long': -118.340696,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.101555, -118.340696]}}},
#  {'name': 'PeopleJar',
#   'lat': 34.1030032,
#   'long': -118.4104684,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.1030032, -118.4104684]}}},
#  {'name': 'Hollywood Interactive Group',
#   'lat': 34.052187,
#   'long': -118.243425,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.052187, -118.243425]}}},
#  {'name': 'Ratchet',
#   'lat': 33.810534,
#   'long': -118.109206,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [33.810534, -118.109206]}}},
#  {'name': 'NOTCOT',
#   'lat': 34.052187,
#   'long': -118.243425,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.052187, -118.243425]}}},
#  {'name': 'Total Immersion',
#   'lat': 34.062164,
#   'long': -118.358787,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.062164, -118.358787]}}},
#  {'name': 'FanPrice',
#   'lat': 38.233786,
#   'long': -122.636071,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [38.233786, -122.636071]}}},
#  {'name': 'SportsGenie',
#   'lat': 34.0522,
#   'long': -118.2429,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.0522, -118.2429]}}},
#  {'name': '6s Marketing',
#   'lat': None,
#   'long': None,
#   'type': {'typepoint': {'type': 'Point', 'coordinates': [None, None]}}},
#  {'name': 'Creative Kingdom Animation Studios Film',
#   'lat': 34.0541081,
#   'long': -118.2595569,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.0541081, -118.2595569]}}},
#  {'name': 'Sceneclips',
#   'lat': 34.05438,
#   'long': -118.26728,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.05438, -118.26728]}}},
#  {'name': 'Mybandstock',
#   'lat': 42.2802675,
#   'long': -83.7420579,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [42.2802675, -83.7420579]}}},
#  {'name': 'Xtreme Widgets',
#   'lat': 33.988687,
#   'long': -118.439532,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [33.988687, -118.439532]}}},
#  {'name': 'TVGla',
#   'lat': 33.988687,
#   'long': -118.439532,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [33.988687, -118.439532]}}},
#  {'name': 'MyFreeImplants',
#   'lat': 34.087825,
#   'long': -118.379493,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.087825, -118.379493]}}},
#  {'name': 'booksRhere',
#   'lat': 34.024817,
#   'long': -118.295117,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.024817, -118.295117]}}},
#  {'name': 'Auditude',
#   'lat': None,
#   'long': None,
#   'type': {'typepoint': {'type': 'Point', 'coordinates': [None, None]}}},
#  {'name': 'The DigiTrust Group',
#   'lat': 33.946126,
#   'long': -118.382385,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [33.946126, -118.382385]}}},
#  {'name': 'kidthing',
#   'lat': 34.045845,
#   'long': -118.237811,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.045845, -118.237811]}}},
#  {'name': 'GetBack',
#   'lat': 34.0342337,
#   'long': -118.4536137,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.0342337, -118.4536137]}}},
#  {'name': 'Vitality',
#   'lat': 34.0485243,
#   'long': -118.4623627,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.0485243, -118.4623627]}}},
#  {'name': 'International Creative Management',
#   'lat': None,
#   'long': None,
#   'type': {'typepoint': {'type': 'Point', 'coordinates': [None, None]}}},
#  {'name': 'Ferrazzi Greenlight',
#   'lat': None,
#   'long': None,
#   'type': {'typepoint': {'type': 'Point', 'coordinates': [None, None]}}},
#  {'name': 'PlayerAuctions',
#   'lat': 34.052187,
#   'long': -118.243425,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.052187, -118.243425]}}},
#  {'name': 'A Unique Presentation',
#   'lat': 34.025386,
#   'long': -118.401729,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.025386, -118.401729]}}},
#  {'name': 'MovieFlix',
#   'lat': 34.070146,
#   'long': -118.365526,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.070146, -118.365526]}}},
#  {'name': 'Wild Brain',
#   'lat': 34.064286,
#   'long': -118.372638,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.064286, -118.372638]}}},
#  {'name': 'Saltlick Labs',
#   'lat': 34.052187,
#   'long': -118.243425,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.052187, -118.243425]}}},
#  {'name': 'Launch 10',
#   'lat': 34.054356,
#   'long': -118.422696,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.054356, -118.422696]}}},
#  {'name': 'ConstructionDeal',
#   'lat': 34.052187,
#   'long': -118.243425,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.052187, -118.243425]}}},
#  {'name': 'PlaceVine',
#   'lat': 34.052187,
#   'long': -118.243425,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.052187, -118.243425]}}},
#  {'name': 'Tadlock Enterprises',
#   'lat': None,
#   'long': None,
#   'type': {'typepoint': {'type': 'Point', 'coordinates': [None, None]}}},
#  {'name': 'Txtms',
#   'lat': 34.052187,
#   'long': -118.243425,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.052187, -118.243425]}}},
#  {'name': 'Zumbox',
#   'lat': None,
#   'long': None,
#   'type': {'typepoint': {'type': 'Point', 'coordinates': [None, None]}}},
#  {'name': 'CrownPeak',
#   'lat': 34.0240159,
#   'long': -118.3767176,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.0240159, -118.3767176]}}},
#  {'name': 'Liferay',
#   'lat': None,
#   'long': None,
#   'type': {'typepoint': {'type': 'Point', 'coordinates': [None, None]}}},
#  {'name': 'Adexa',
#   'lat': None,
#   'long': None,
#   'type': {'typepoint': {'type': 'Point', 'coordinates': [None, None]}}},
#  {'name': 'Awareness Technologies',
#   'lat': 33.9812355,
#   'long': -118.44097,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [33.9812355, -118.44097]}}},
#  {'name': 'Fonality',
#   'lat': 33.9874429,
#   'long': -118.3846632,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [33.9874429, -118.3846632]}}},
#  {'name': 'GoGo Lingo',
#   'lat': 34.052187,
#   'long': -118.243425,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.052187, -118.243425]}}},
#  {'name': 'Creative Artists Agency',
#   'lat': 34.0586832,
#   'long': -118.4158174,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.0586832, -118.4158174]}}},
#  {'name': 'Table For Six',
#   'lat': 34.058324,
#   'long': -118.441888,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.058324, -118.441888]}}},
#  {'name': 'Zed',
#   'lat': None,
#   'long': None,
#   'type': {'typepoint': {'type': 'Point', 'coordinates': [None, None]}}},
#  {'name': 'National Lampoon',
#   'lat': 34.0975446,
#   'long': -118.3685931,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.0975446, -118.3685931]}}},
#  {'name': 'Maas Global Solutions Corporation',
#   'lat': None,
#   'long': None,
#   'type': {'typepoint': {'type': 'Point', 'coordinates': [None, None]}}},
#  {'name': 'Sennari',
#   'lat': 33.9782287,
#   'long': -118.4303427,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [33.9782287, -118.4303427]}}},
#  {'name': 'Sennari',
#   'lat': 33.9782287,
#   'long': -118.4303427,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [33.9782287, -118.4303427]}}},
#  {'name': 'Broken Knuckles Clothing',
#   'lat': 34.0760614,
#   'long': -118.3729534,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.0760614, -118.3729534]}}},
#  {'name': 'LeadPoint',
#   'lat': 34.054212,
#   'long': -118.464454,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.054212, -118.464454]}}},
#  {'name': 'Equator',
#   'lat': None,
#   'long': None,
#   'type': {'typepoint': {'type': 'Point', 'coordinates': [None, None]}}},
#  {'name': 'Univision',
#   'lat': 33.9778907,
#   'long': -118.3925179,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [33.9778907, -118.3925179]}}},
#  {'name': 'ReferQuest',
#   'lat': 34.031222,
#   'long': -118.420346,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.031222, -118.420346]}}},
#  {'name': 'Trustworthy',
#   'lat': 34.049246,
#   'long': -118.395346,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.049246, -118.395346]}}},
#  {'name': 'KlickSports',
#   'lat': 34.0431973,
#   'long': -118.445584,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.0431973, -118.445584]}}},
#  {'name': 'Boom Studios',
#   'lat': 34.060523,
#   'long': -118.367703,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.060523, -118.367703]}}},
#  {'name': 'Link Gateway',
#   'lat': 34.052187,
#   'long': -118.243425,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.052187, -118.243425]}}},
#  {'name': 'TechForward',
#   'lat': 34.146503,
#   'long': -118.613385,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.146503, -118.613385]}}},
#  {'name': 'Mobile Messenger',
#   'lat': 33.979956,
#   'long': -118.393979,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [33.979956, -118.393979]}}},
#  {'name': 'ABCO TECHNOLOGY',
#   'lat': 33.978825,
#   'long': -118.394889,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [33.978825, -118.394889]}}},
#  {'name': 'GaimTheory',
#   'lat': None,
#   'long': None,
#   'type': {'typepoint': {'type': 'Point', 'coordinates': [None, None]}}},
#  {'name': 'eModeration',
#   'lat': 34.1538216,
#   'long': -118.4662511,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.1538216, -118.4662511]}}},
#  {'name': "Blip'd",
#   'lat': 34.0760614,
#   'long': -118.3729534,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.0760614, -118.3729534]}}},
#  {'name': 'Jobspring Partners',
#   'lat': 34.057346,
#   'long': -118.447078,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.057346, -118.447078]}}},
#  {'name': 'Workbridge Associates',
#   'lat': 34.057346,
#   'long': -118.447078,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.057346, -118.447078]}}},
#  {'name': 'Grindr',
#   'lat': 34.11275,
#   'long': -118.386224,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.11275, -118.386224]}}},
#  {'name': 'Ranker',
#   'lat': 34.1012181,
#   'long': -118.325739,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.1012181, -118.325739]}}},
#  {'name': 'Epsilon Concepts',
#   'lat': 34.051508,
#   'long': -118.262233,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.051508, -118.262233]}}},
#  {'name': 'Here Media',
#   'lat': None,
#   'long': None,
#   'type': {'typepoint': {'type': 'Point', 'coordinates': [None, None]}}},
#  {'name': 'Silvatar Media',
#   'lat': 34.1036353,
#   'long': -118.293316,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.1036353, -118.293316]}}},
#  {'name': 'Global Digital Media Xchange',
#   'lat': 33.943108,
#   'long': -118.374904,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [33.943108, -118.374904]}}},
#  {'name': 'BrandBucket',
#   'lat': None,
#   'long': None,
#   'type': {'typepoint': {'type': 'Point', 'coordinates': [None, None]}}},
#  {'name': 'Sensis',
#   'lat': 34.0490571,
#   'long': -118.2593181,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.0490571, -118.2593181]}}},
#  {'name': 'Fed Receiver',
#   'lat': None,
#   'long': None,
#   'type': {'typepoint': {'type': 'Point', 'coordinates': [None, None]}}},
#  {'name': 'Huge',
#   'lat': 34.167304,
#   'long': -118.373614,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.167304, -118.373614]}}},
#  {'name': 'HauteLook',
#   'lat': None,
#   'long': None,
#   'type': {'typepoint': {'type': 'Point', 'coordinates': [None, None]}}},
#  {'name': 'Velti',
#   'lat': None,
#   'long': None,
#   'type': {'typepoint': {'type': 'Point', 'coordinates': [None, None]}}},
#  {'name': 'Daimer Industries',
#   'lat': None,
#   'long': None,
#   'type': {'typepoint': {'type': 'Point', 'coordinates': [None, None]}}},
#  {'name': 'Yoostar',
#   'lat': 34.052187,
#   'long': -118.243425,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.052187, -118.243425]}}},
#  {'name': 'WebPurify',
#   'lat': 34.052187,
#   'long': -118.243425,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.052187, -118.243425]}}},
#  {'name': 'eblizz',
#   'lat': 34.0163012,
#   'long': -118.4920896,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.0163012, -118.4920896]}}},
#  {'name': 'SchoolRack',
#   'lat': 34.0386656,
#   'long': -118.4221519,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.0386656, -118.4221519]}}},
#  {'name': 'Painless Productions',
#   'lat': None,
#   'long': None,
#   'type': {'typepoint': {'type': 'Point', 'coordinates': [None, None]}}},
#  {'name': 'Cocodot',
#   'lat': 34.104692,
#   'long': -118.375698,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.104692, -118.375698]}}},
#  {'name': 'Duane Morris LLP',
#   'lat': None,
#   'long': None,
#   'type': {'typepoint': {'type': 'Point', 'coordinates': [None, None]}}},
#  {'name': 'Brierley+Partners',
#   'lat': None,
#   'long': None,
#   'type': {'typepoint': {'type': 'Point', 'coordinates': [None, None]}}},
#  {'name': 'Moviepilot',
#   'lat': 34.0522342,
#   'long': -118.2436849,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.0522342, -118.2436849]}}},
#  {'name': 'High Density Networks',
#   'lat': 34.058101,
#   'long': -118.235338,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.058101, -118.235338]}}},
#  {'name': 'ITTAGS',
#   'lat': 34.052187,
#   'long': -118.243425,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.052187, -118.243425]}}},
#  {'name': 'Iteego',
#   'lat': 34.052187,
#   'long': -118.243425,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.052187, -118.243425]}}},
#  {'name': 'Global Fitness Media',
#   'lat': 34.054318,
#   'long': -118.462876,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.054318, -118.462876]}}},
#  {'name': 'Zugara',
#   'lat': None,
#   'long': None,
#   'type': {'typepoint': {'type': 'Point', 'coordinates': [None, None]}}},
#  {'name': 'CallFire',
#   'lat': None,
#   'long': None,
#   'type': {'typepoint': {'type': 'Point', 'coordinates': [None, None]}}},
#  {'name': 'AECOM Technology',
#   'lat': 34.0507962,
#   'long': -118.2568615,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.0507962, -118.2568615]}}},
#  {'name': 'Hythiam',
#   'lat': None,
#   'long': None,
#   'type': {'typepoint': {'type': 'Point', 'coordinates': [None, None]}}},
#  {'name': 'University of Southern California',
#   'lat': None,
#   'long': None,
#   'type': {'typepoint': {'type': 'Point', 'coordinates': [None, None]}}},
#  {'name': 'DTT',
#   'lat': None,
#   'long': None,
#   'type': {'typepoint': {'type': 'Point', 'coordinates': [None, None]}}},
#  {'name': 'Culture Jam',
#   'lat': 34.0137151,
#   'long': -118.4660597,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.0137151, -118.4660597]}}},
#  {'name': 'California 7 Studios',
#   'lat': None,
#   'long': None,
#   'type': {'typepoint': {'type': 'Point', 'coordinates': [None, None]}}},
#  {'name': 'Pipit Interactive',
#   'lat': 34.045499,
#   'long': -118.47036,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.045499, -118.47036]}}},
#  {'name': 'Top Rated Website Designers',
#   'lat': 33.9933257,
#   'long': -118.3987842,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [33.9933257, -118.3987842]}}},
#  {'name': 'SOA Software',
#   'lat': None,
#   'long': None,
#   'type': {'typepoint': {'type': 'Point', 'coordinates': [None, None]}}},
#  {'name': 'IVR Technologies',
#   'lat': 34.050066,
#   'long': -118.253161,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [34.050066, -118.253161]}}}]

# %%
LosAngeles[0]["name"]
# Out:
# 'Helio'

# %%
LosAngeles[0]["offices"]
# Out:
# [{'city': 'Los Angeles', 'latitude': 34.057498, 'longitude': -118.446596}]

# %%
len(LosAngeles_new)
# Out:
# 220

# %%
df_LosAngeles = pd.DataFrame(LosAngeles_new)
df_LosAngeles
# Out:
#                             name        lat        long  \
# 0                          Helio  34.057498 -118.446596
# 1                        Stickam  34.051409 -118.254558
# 2                        Ustream        NaN         NaN
# 3                         TripUp  34.052187 -118.243425
# 4                       Eventful        NaN         NaN
# ..                           ...        ...         ...
# 215         California 7 Studios        NaN         NaN
# 216            Pipit Interactive  34.045499 -118.470360
# 217  Top Rated Website Designers  33.993326 -118.398784
# 218                 SOA Software        NaN         NaN
# 219             IVR Technologies  34.050066 -118.253161
#
#                                                   type
# 0    {'typepoint': {'type': 'Point', 'coordinates':...
# 1    {'typepoint': {'type': 'Point', 'coordinates':...
# 2    {'typepoint': {'type': 'Point', 'coordinates':...
# 3    {'typepoint': {'type': 'Point', 'coordinates':...
# 4    {'typepoint': {'type': 'Point', 'coordinates':...
# ..                                                 ...
# 215  {'typepoint': {'type': 'Point', 'coordinates':...
# 216  {'typepoint': {'type': 'Point', 'coordinates':...
# 217  {'typepoint': {'type': 'Point', 'coordinates':...
# 218  {'typepoint': {'type': 'Point', 'coordinates':...
# 219  {'typepoint': {'type': 'Point', 'coordinates':...
#
# [220 rows x 4 columns]

# %%
df_LosAngeles.isna().sum()
# Out:
# name     0
# lat     52
# long    52
# type     0
# dtype: int64

# %%
df_LosAngeles_copy = df_LosAngeles.copy()

# %%
df_LosAngeles_copy.dropna(subset=['lat', 'long'],inplace=True)

# %%
df_LosAngeles_copy.isna().sum()
# Out:
# name    0
# lat     0
# long    0
# type    0
# dtype: int64

# %%
len(df_LosAngeles_copy)
# Out:
# 168

# %%
df_LosAngeles_copy
# Out:
#                             name        lat        long  \
# 0                          Helio  34.057498 -118.446596
# 1                        Stickam  34.051409 -118.254558
# 3                         TripUp  34.052187 -118.243425
# 5                      ScanScout  34.050887 -118.459995
# 6                      WebbAlert  34.052187 -118.243425
# ..                           ...        ...         ...
# 210             AECOM Technology  34.050796 -118.256861
# 214                  Culture Jam  34.013715 -118.466060
# 216            Pipit Interactive  34.045499 -118.470360
# 217  Top Rated Website Designers  33.993326 -118.398784
# 219             IVR Technologies  34.050066 -118.253161
#
#                                                   type
# 0    {'typepoint': {'type': 'Point', 'coordinates':...
# 1    {'typepoint': {'type': 'Point', 'coordinates':...
# 3    {'typepoint': {'type': 'Point', 'coordinates':...
# 5    {'typepoint': {'type': 'Point', 'coordinates':...
# 6    {'typepoint': {'type': 'Point', 'coordinates':...
# ..                                                 ...
# 210  {'typepoint': {'type': 'Point', 'coordinates':...
# 214  {'typepoint': {'type': 'Point', 'coordinates':...
# 216  {'typepoint': {'type': 'Point', 'coordinates':...
# 217  {'typepoint': {'type': 'Point', 'coordinates':...
# 219  {'typepoint': {'type': 'Point', 'coordinates':...
#
# [168 rows x 4 columns]

# %%
LA_group = folium.FeatureGroup(name="Los Angeles")

# %%
HeatMap(data=df_LosAngeles_copy[["lat", "long"]], radius=15,
       gradient = {0.4: 'yellow', 0.65: 'orange', 1: 'red'}).add_to(LA_group)

# %%
LA_group.add_to(LA_map)

# %%
LA_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b32ba469e389eb0bb62e711cbe73ebec {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@master/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b32ba469e389eb0bb62e711cbe73ebec&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_b32ba469e389eb0bb62e711cbe73ebec = L.map(
#                 &quot;map_b32ba469e389eb0bb62e711cbe73ebec&quot;,
#                 {
#                     center: [34.0218593, -118.498265],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9405030f5ec6dda82e842d6853f380ba = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b32ba469e389eb0bb62e711cbe73ebec);
#
#
#             var feature_group_e008ec325e70443861af19448c277d65 = L.featureGroup(
#                 {}
#             ).addTo(map_b32ba469e389eb0bb62e711cbe73ebec);
#
#
#             var heat_map_b8b76fd6f27e4a6ccb506b80096e7e07 = L.heatLayer(
#                 [[34.057498, -118.446596], [34.051409, -118.254558], [34.052187, -118.243425], [34.050887, -118.459995], [34.052187, -118.243425], [34.052187, -118.243425], [34.101617, -118.327071], [34.062262, -118.348198], [33.979033, -118.423423], [37.09024, -95.712891], [37.09024, -95.712891], [34.031276, -118.456806], [34.0481711, -118.4419012], [33.959799, -118.343938], [34.064491, -118.42749], [33.982431, -118.426707], [34.0065488, -118.3923578], [34.047312, -118.445243], [34.051368, -118.256305], [34.128046, -118.289065], [34.059721, -118.425401], [34.062253, -118.3543243], [34.064629, -118.469316], [33.988735, -118.368871], [37.446823, -122.161523], [34.029209, -118.289344], [33.954874, -118.396507], [34.0618146, -118.2899533], [34.080772, -118.3891962], [33.988735, -118.368871], [34.041037, -118.23341], [34.052187, -118.243425], [34.047104, -118.434213], [34.043948, -118.468204], [34.089679, -118.292618], [34.062504, -118.354605], [34.081952, -118.357658], [34.0486806, -118.2587784], [34.018349, -118.486889], [34.052187, -118.243425], [34.050907, -118.253254], [34.043228, -118.46856], [33.9772881, -118.4258761], [34.044939, -118.419067], [34.031646, -118.455352], [34.085749, -118.343791], [34.052187, -118.243425], [34.0634, -118.445257], [34.05285, -118.264858], [34.0905865, -118.3905856], [34.052187, -118.243425], [34.052187, -118.243425], [34.080651, -118.334436], [34.029956, -118.308943], [34.037542, -118.441178], [34.0815238, -118.3826743], [34.052187, -118.243425], [33.903544, -118.265655], [33.934558, -118.3962622], [34.052187, -118.243425], [34.044931, -118.23497], [34.0748, -118.288536], [34.1395597, -118.3870991], [34.048573, -118.25957], [34.05304, -118.46643], [34.039585, -118.255804], [34.06226, -118.343648], [34.031646, -118.455352], [34.05775, -118.4138], [34.052187, -118.243425], [34.1015548, -118.3406957], [34.048545, -118.339502], [34.052107, -118.385271], [34.061368, -118.416334], [34.052187, -118.243425], [33.987978, -118.362442], [34.086348, -118.488226], [34.070436, -118.350486], [34.052187, -118.243425], [33.946285, -118.38823], [34.054259, -118.414064], [34.062262, -118.348198], [34.052187, -118.243425], [34.098028, -118.353624], [34.005914, -118.488129], [34.101555, -118.340696], [34.070436, -118.350486], [34.052187, -118.243425], [33.946285, -118.38823], [34.054259, -118.414064], [34.062262, -118.348198], [34.052187, -118.243425], [34.098028, -118.353624], [34.005914, -118.488129], [34.101555, -118.340696], [34.1030032, -118.4104684], [34.052187, -118.243425], [33.810534, -118.109206], [34.052187, -118.243425], [34.062164, -118.358787], [38.233786, -122.636071], [34.0522, -118.2429], [34.0541081, -118.2595569], [34.05438, -118.26728], [42.2802675, -83.7420579], [33.988687, -118.439532], [33.988687, -118.439532], [34.087825, -118.379493], [34.024817, -118.295117], [33.946126, -118.382385], [34.045845, -118.237811], [34.0342337, -118.4536137], [34.0485243, -118.4623627], [34.052187, -118.243425], [34.025386, -118.401729], [34.070146, -118.365526], [34.064286, -118.372638], [34.052187, -118.243425], [34.054356, -118.422696], [34.052187, -118.243425], [34.052187, -118.243425], [34.052187, -118.243425], [34.0240159, -118.3767176], [33.9812355, -118.44097], [33.9874429, -118.3846632], [34.052187, -118.243425], [34.0586832, -118.4158174], [34.058324, -118.441888], [34.0975446, -118.3685931], [33.9782287, -118.4303427], [33.9782287, -118.4303427], [34.0760614, -118.3729534], [34.054212, -118.464454], [33.9778907, -118.3925179], [34.031222, -118.420346], [34.049246, -118.395346], [34.0431973, -118.445584], [34.060523, -118.367703], [34.052187, -118.243425], [34.146503, -118.613385], [33.979956, -118.393979], [33.978825, -118.394889], [34.1538216, -118.4662511], [34.0760614, -118.3729534], [34.057346, -118.447078], [34.057346, -

# %%
SM_lat = 34.0195
SM_long = -118.4912

# %%
SM_map = folium.Map(location = [SM_lat, SM_long], zoom_start=10)
folium.Marker([SM_lat, SM_long]).add_to(SM_map)
folium.Circle([SM_lat, SM_long], radius=500).add_to(SM_map)
folium.Circle([SM_lat, SM_long], radius=1000).add_to(SM_map)
folium.Circle([SM_lat, SM_long], radius=3000).add_to(SM_map)

# %%
SM_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a93f4e7f60b168a62c503731bbd17ee7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a93f4e7f60b168a62c503731bbd17ee7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_a93f4e7f60b168a62c503731bbd17ee7 = L.map(
#                 &quot;map_a93f4e7f60b168a62c503731bbd17ee7&quot;,
#                 {
#                     center: [34.0195, -118.4912],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_470e2e77675a30d86ca5641d335febf8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a93f4e7f60b168a62c503731bbd17ee7);
#
#
#             var marker_3dd165bd9f669b71524938aa9807dd14 = L.marker(
#                 [34.0195, -118.4912],
#                 {}
#             ).addTo(map_a93f4e7f60b168a62c503731bbd17ee7);
#
#
#             var circle_b0657dab0dfedb11365e66c29fd7f4b1 = L.circle(
#                 [34.0195, -118.4912],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 500, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a93f4e7f60b168a62c503731bbd17ee7);
#
#
#             var circle_16eddaf037123df388d72338bc0b5cc5 = L.circle(
#                 [34.0195, -118.4912],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a93f4e7f60b168a62c503731bbd17ee7);
#
#
#             var circle_f72eb475048463fa1cee619ac67f9c03 = L.circle(
#                 [34.0195, -118.4912],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a93f4e7f60b168a62c503731bbd17ee7);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
SM_lat_updated = 34.03327701719273
SM_long_updated = -118.47431848484814

# %%
SM_map_updated = folium.Map(location = [SM_lat, SM_long], zoom_start=10)
folium.Marker([SM_lat_updated, SM_long_updated]).add_to(SM_map)
folium.Circle([SM_lat_updated, SM_long_updated], radius=500).add_to(SM_map_updated)
folium.Circle([SM_lat_updated, SM_long_updated], radius=1000).add_to(SM_map_updated)
folium.Circle([SM_lat_updated, SM_long_updated], radius=2000).add_to(SM_map_updated)
folium.Circle([SM_lat_updated, SM_long_updated], radius=3000).add_to(SM_map_updated)

# %%
SM_map_updated
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_118f26d420317c5c3950265e360da639 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_118f26d420317c5c3950265e360da639&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_118f26d420317c5c3950265e360da639 = L.map(
#                 &quot;map_118f26d420317c5c3950265e360da639&quot;,
#                 {
#                     center: [34.0195, -118.4912],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_936f897d77a5ac9a332ef4218d53f14e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_118f26d420317c5c3950265e360da639);
#
#
#             var circle_244fdee089d165e2c6f434535aecb0c7 = L.circle(
#                 [34.03327701719273, -118.47431848484814],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 500, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_118f26d420317c5c3950265e360da639);
#
#
#             var circle_9ea3a83e9c321c26ee729049c35fb142 = L.circle(
#                 [34.03327701719273, -118.47431848484814],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_118f26d420317c5c3950265e360da639);
#
#
#             var circle_6244b5e8fcc4905f11a3cd12d97c62e8 = L.circle(
#                 [34.03327701719273, -118.47431848484814],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_118f26d420317c5c3950265e360da639);
#
#
#             var circle_2f480170f6813e867591b4cf91cdebcd = L.circle(
#                 [34.03327701719273, -118.47431848484814],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_118f26d420317c5c3950265e360da639);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
def querySM (query, location, radius):

    if " " in query.strip():
           query_ok = query.strip().replace(" ","%20")
    else:
           query_ok = query
    url = f"https://api.foursquare.com/v3/places/search?query={query_ok}&ll={str(location[0]).strip()}%2C{str(location[1]).strip()}&radius={radius}&limit=50"
    headers =  {
    "Accept": "application/json",
    "Authorization": f"{client_key}" 
    }
    response = requests.get(url, headers=headers)
    
    if response:
        response=response.json()['results']
        new_list = [ {"name" : i["name"],
                      "lat"  : i["geocodes"]["main"]["latitude"],
                      "long" : i["geocodes"]["main"]["longitude"],
                      "type" : {"typepoint":
                                  {"type": "Point",
                                   "coordinates": [lat, lon]}}} for i in response]
    return new_list

# %%
daycare = querySM("daycare",[34.03327701719273, -118.47431848484814],3000)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# /var/folders/cm/fc2_w_693_s292_lj65rkvnw0000gn/T/ipykernel_6282/2195729330.py in <module>
# ----> 1 daycare = querySM("daycare",[34.03327701719273, -118.47431848484814],3000)
#
# /var/folders/cm/fc2_w_693_s292_lj65rkvnw0000gn/T/ipykernel_6282/3582139343.py in querySM(query, location, radius)
#      20                                   {"type": "Point",
#      21                                    "coordinates": [lat, lon]}}} for i in response]
# ---> 22     return new_list
#
# UnboundLocalError: local variable 'new_list' referenced before assignment

# %%
design_studio = querySM("Design_studio",[34.03327701719273, -118.47431848484814],3000)

# %%
airport = querySM("airport",[34.03327701719273, -118.47431848484814],3000)

# %%
bar = querySM("bar",[34.03327701719273, -118.47431848484814],3000)

# %%
Starbucks = querySM("starbucks",[34.03327701719273, -118.47431848484814],3000)

# %%
basketball_stadium = querySM("basketball_stadium",[34.03327701719273, -118.47431848484814],3000)

# %%
groomer = querySM("Pet Grooming Service",[34.03327701719273, -118.47431848484814],3000)

# %%
vegan = querySM("vegan",[34.03327701719273, -118.47431848484814],3000)
